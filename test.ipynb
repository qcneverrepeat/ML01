# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import importlib
# importlib.reload(...) 重新载入包，用于包的调试，注意：首次调用不可以使用该函数

# %%
from sklearn.datasets import load_iris

data1 = pd.read_excel('data/sales_data.xls')
data2 = pd.read_excel('data/model.xls')
data3 = pd.read_csv('data/imports-85.data', header=None)
data4 = load_iris()

# %%
X = data4.data
y = data4.target

# %%
import ID3
import CART 
importlib.reload(ID3)
importlib.reload(CART)
# dt = ID3.Tree()
dt = CART.Tree()
dt.fit(X,y)
# (dt.predict(X)==y)

dot = dt.tree2DOT()

im = pydotplus.graph_from_dot_data(dot)
Image(im.create_png())

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X,y)
dt.predict(X)==y
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
import pydotplus
from IPython.display import Image

# %%
dot = '''
digraph g {
node [shape=box, style="filled, rounded", color="pink", fontname=helvetica] ;1 [label=<petal length (cm) &le; 4.95<br/>gini = 0.168<br/>samples = 54<br/>value = [0, 49, 5]<br/>class = 1>]
2 [label="len <= 4 \n gini = 0.2 \n ins_num = 34 \n feature_num = 4 \n class = 1 "]
3 [label=" t "]
4 [label=" f "]

}
'''
im = pydotplus.graph_from_dot_data(dot)
Image(im.create_png())

# %%
print(dot_data)
# Out:
# digraph Tree {
# node [shape=box, style="filled, rounded", color="black", fontname=helvetica] ;
# edge [fontname=helvetica] ;
# 0 [label=<petal length (cm) &le; 2.45<br/>gini = 0.667<br/>samples = 150<br/>value = [50, 50, 50]<br/>class = 0>, fillcolor="#e5813900"] ;
# 1 [label=<gini = 0.0<br/>samples = 50<br/>value = [50, 0, 0]<br/>class = 0>, fillcolor="#e58139ff"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label=<petal width (cm) &le; 1.75<br/>gini = 0.5<br/>samples = 100<br/>value = [0, 50, 50]<br/>class = 1>, fillcolor="#39e58100"] ;
# 0 -> 2 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 3 [label=<petal length (cm) &le; 4.95<br/>gini = 0.168<br/>samples = 54<br/>value = [0, 49, 5]<br/>class = 1>, fillcolor="#39e581e5"] ;
# 2 -> 3 ;
# 4 [label=<petal width (cm) &le; 1.65<br/>gini = 0.041<br/>samples = 48<br/>value = [0, 47, 1]<br/>class = 1>, fillcolor="#39e581fa"] ;
# 3 -> 4 ;
# ...

# %%
from IPython.display import Image  
from sklearn import tree
import pydotplus 
dot_data = tree.export_graphviz(dt, out_file=None, 
                         feature_names=data4.feature_names,  
                         class_names=['0','1','2'],  
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())
